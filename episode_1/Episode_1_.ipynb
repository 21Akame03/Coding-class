# %% [markdown]
# # Turtles Graphics
#
# ***Note : No Turtles were harmed during the production of this code***

# %%
# install ColabTurle library
# !pip install ColabTurtle

# import the Turtle package from the ColabTurtle library
from ColabTurtle import Turtle as turtle
from math import pi


#calling on the initialize method from class Turtle
turtle.initializeTurtle()

#show the turtle
turtle.is_turtle_visible = False

turtle.color("red")
turtle.speed(13)


# find the width and height of the window and divide both by 2 to find the center of the window
# set the turtle to the position that is the middle of the window
def reset_turtle() :
  turtle.setx(turtle.window_width()/2)
  turtle.sety(turtle.window_height()/2)
  turtle.clear()

  print(turtle.window_height())
  print(turtle.window_width())
# Out:
# ...
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#
#         <g visibility=hidden transform="rotate(360,400,250) translate(382, 232)">
# ...

# %%
# resets the display
reset_turtle()


def tcircle(radius):

    def regular_polygon(l, n):
      """draws a regular polygon of n amount sides of length l
      that is supposed to appear like a circle.
      function by cdlane from a stackoverflow post"""
      for _ in range(n):
          turtle.forward(l)
          turtle.left(360 / n)


    #circumference (c)= 2*pi*radius
    circumference = 2 * pi * radius


    #n = amount of lines or corners, it defines the accuracy of the circle
    number_of_corners = 15 # lower number to decrease drawing time (can be any float or int)

    #circumference (c) = ca.  l * n
    #l = length of individual lines 
    length = circumference / number_of_corners


    # call on the function 
    regular_polygon(int(length),number_of_corners)




# count from 20 to 210 incrementing by 5
for i in range(20, 210, 5):
  #circle_example
  tcircle(i)
  print(i)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...
